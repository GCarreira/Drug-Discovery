# %% [markdown]
# <a href="https://colab.research.google.com/github/GCarreira/Drug-Discovery/blob/main/Drug_Discovery_Alura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'
df= pd.read_csv (url_dados, compression='zip')

# %%
df.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
df['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
# Desafio 1 (Investigar por que a classe tratamento é tão desbalanceada)

# %%
# Desafio 2 (5 ultimas linhas do dataframe)
df.tail()
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %%
# Desafio 3 (encontrar o valor em porcentagem) resp: normalize = True
df['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
df['tratamento'].value_counts().plot.pie()

plt.title('Tipo de tratamento')
plt.legend(loc = 'best')

plt.show()

# %%
df['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %%
df['dose'].value_counts(normalize = True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
# Desafio 4 (quantas drogas diferentes foram testadas?) resp: 23
df = df.rename(columns={'droga':'composto'})
df['composto'].value_counts()
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# bef38f2fd       1
# bc21046fe       1
# c7e535136       1
# 2b06f0b4b       1
# 19b95658c       1
# Name: composto, Length: 3289, dtype: int64

# %%
df['tempo'].value_counts().plot.bar(color='green')
plt.title('Relação: Doses x Tempo')
plt.ylabel('Quantidade de amostras de cada grupo')
plt.xlabel('Intervalo entre doses')
# Out:
# Text(0.5, 0, 'Intervalo entre doses')

# %% [markdown]
# Desafio 01: Investigar por que a classe tratamento é tão desbalanceada?
#
# DEsafio 02: Plotar as 5 últimas linhas da tabela
#
# Desafio 03: Proporção das classes tratamento.
#
# Desafio 04: Quantas tipos de drogas foram investigados.
#
# Desafio 05: Procurar na documentação o método query(pandas).
#
# Desafio 06: Renomear as colunas tirando o hífen.
#
# Desafio 07: Deixar os gráficos bonitões. (Matplotlib.pyplot)
#
# Desafio 08: Resumo do que você aprendeu com os dados

# %%
#Desafio 06: Renomear as colunas tirando o hífen. ### df.columns = df.columns.str.replace('-', '')

df.rename(columns=lambda x: x.replace('-', ''), inplace = True)
df.columns
# Out:
# Index(['id', 'tratamento', 'tempo', 'dose', 'composto', 'g0', 'g1', 'g2', 'g3',
#        'g4',
#        ...
#        'c90', 'c91', 'c92', 'c93', 'c94', 'c95', 'c96', 'c97', 'c98', 'c99'],
#       dtype='object', length=877)

# %%
df = df.rename(columns={'droga':'composto'})

# %%
df.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
cod_compostos = df['composto'].value_counts().index[0:5]
df.query('composto in @cod_compostos')
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
### Desafio 07: Deixar os gráficos bonitões. (Matplotlib.pyplot)
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
#plt.title('Ranking 5 principais compostos')     ###Título pelo Seaborn abaixo.
sns.set()
ax = sns.countplot(x = 'composto', data= df.query('composto in @cod_compostos'), order=cod_compostos ).set_title('Ranking 5 principais compostos', fontsize=20)
# ax.set_title('Ranking 5 principais compostos') (mais comum chamar o gráfico de 'ax' e incluir título em uma nova linha e não como está acima)
plt.show() ###Exclui textos extras sob o gráfico.

# Desafio: Colocar o gráfico em ordem. # (order=compostos)
# Desafio: Colocar nome nos eixos e alterar tamanho da fonte.
 
 ax = sns.countplot()

# %% [markdown]
# Aula2
#
# Desafio 01: Ordenar o gráfico acima 'countplot'. Feito
#
# Desafio 02: Melhorar a visualização alterando tamanho da fonte...
#
# Desafio 03: Plotar os histogramas com seaborn
#
# Desafio 04: Estudar sobre as estatíticas retornadas no .describe()
#
# Desafio 05: Refletir sobre a manipulação do tamanho das visualizações.
#
# Desafio 06: Fazer outras análises com o boxplot e até com o histograma.
#
# Desafio 07: Resumo do que você aprendeu com os dados

# %%
# HISTOGRAMA PADRÃO DO PANDAS 
#df['g0'].hist() ##Divide as caixas de medidas conforme a quantidade, mas deixa muita distancia entre os intervalos.
#df['g0'].hist(bins = 50) ## Divide as caixas em 50 partes.
df['g0'].hist(bins = 100) ## Dividindo em 100 conseguimos ter noção exata da curva.

# %%
df['c60'].hist(bins = 100)

# %%
df[['g0', 'g1']]
df[['g0', 'g1']].hist(bins=30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f901b89fc10>,
# ...
#       dtype=object)

# %%
df.loc[:, 'g0': 'g771'].describe()
# Out:
#                  g0            g1  ...          g770          g771
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean       0.248366     -0.095684  ...     -0.219210      0.101524
# std        1.393399      0.812363  ...      1.326193      1.417674
# min       -5.513000     -5.737000  ...    -10.000000    -10.000000
# 25%       -0.473075     -0.562200  ...     -0.554400     -0.523800
# 50%       -0.008850     -0.046600  ...      0.028700     -0.006500
# 75%        0.525700      0.403075  ...      0.496400      0.536950
# max       10.000000      5.039000  ...     10.000000     10.000000
#
# [8 rows x 772 columns]

# %%
### '.T' ponto T = inverte a ordem de amostra, fazendo com que as médias sejam os nomes das colunas. Bom para gerar gráficos com grandes resultados.
df.loc[:, 'g0': 'g771'].describe().T
# Out:
#         count      mean       std     min       25%      50%       75%     max
# g0    23814.0  0.248366  1.393399  -5.513 -0.473075 -0.00885  0.525700  10.000
# g1    23814.0 -0.095684  0.812363  -5.737 -0.562200 -0.04660  0.403075   5.039
# g2    23814.0  0.152253  1.035731  -9.104 -0.437750  0.07520  0.663925   8.257
# g3    23814.0  0.081971  0.950012  -5.998 -0.429575  0.00805  0.463400  10.000
# g4    23814.0  0.057347  1.032091  -6.369 -0.470925 -0.02690  0.465375  10.000
# ...       ...       ...       ...     ...       ...      ...       ...     ...
# g767  23814.0 -0.076251  1.115477 -10.000 -0.506200  0.00990  0.511175   6.317
# g768  23814.0  0.134162  0.951264  -4.269 -0.353100  0.00540  0.409075  10.000
# g769  23814.0 -0.128018  1.230636 -10.000 -0.544600  0.00060  0.498500   5.911
# g770  23814.0 -0.219210  1.326193 -10.000 -0.554400  0.02870  0.496400  10.000
# g771  23814.0  0.101524  1.417674 -10.000 -0.523800 -0.00650  0.536950  10.000
#
# [772 rows x 8 columns]

# %%
df.loc[:, 'g0' : 'g771'].describe().T['mean'].hist(bins = 90)
plt.show()

# %%
df.loc[:, 'g0': 'g771'].describe().T['min'].hist(bins = 30)

# %%
df.loc[:, 'g0': 'g771'].describe().T['max'].hist(bins = 30)

# %%
### Desafio 6: Usar o boxplot
sns.boxplot(x= 'g0', data=df)

# %%
sns.boxplot(x= 'g0', y='tratamento', data=df)

# %%
plt.figure(figsize= (10, 8))
sns.boxplot(y= 'g0', x='tratamento', data=df)

# %% [markdown]
# AULA 03

# %%
### Usar a função crosstab para criar tabela de frequência.
pd.crosstab(df.dose, df.tempo)
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
## Assim criamos 2 índices. Temos 'dose e tempo' dentro de uma classe maior 'tratamento'.
pd.crosstab([df.dose, df.tempo], df.tratamento)
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
### Neste caso todos os dados da tabela juntos somam 100%. ## Para analisar melhor, precisamos da porcentagem por linhas. Portanto (normalize='index').
pd.crosstab([df.dose, df.tempo], df.tratamento, normalize=True)
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.012640   0.150542
#      48         0.014403   0.168430
#      72         0.012892   0.151172
# D2   24         0.012808   0.150374
#      48         0.012808   0.150794
#      72         0.012808   0.150332

# %%
### Agora temos os 100% das amostras (com e sem droga) divididas na mesma linha.
pd.crosstab([df.dose, df.tempo], df.tratamento, normalize='index')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
### Compara a média de resposta do "g0" em relação às doses e o tempo entre aplicações.
pd.crosstab([df.dose, df.tempo], df.tratamento, values= df.g0, aggfunc='mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
#Desafio: Agrupar com a função Groupby
df[['g0','dose', 'tempo', 'tratamento']].groupby(by=['tratamento', 'dose', 'tempo',]).mean()
# Out:
#                                g0
# tratamento   dose tempo
# com_controle D1   24    -0.251760
#                   48    -0.122773
#                   72    -0.295271
#              D2   24     0.010754
#                   48     0.013174
#                   72     0.070250
# com_droga    D1   24     0.367996
#                   48     0.412469
#                   72     0.286250
#              D2   24     0.115253
#                   48     0.214480
#                   72     0.253439

# %%
###Gráfico de dispersão (scatter), onde cada ponto representa os valores de uma linha das colunas g0 e g3. 
sns.scatterplot(x= 'g0', y= 'g3', data= df)

# %%
### Aqui vemos que quanto maior os valores do eixo x, menor os do eixo y. 
sns.scatterplot(x= 'g0', y= 'g8', data=df)

# %%
###Usar o lmplot com função de linha para apontar a direção das amostras, a cor da linha precisa ser definida.
sns.lmplot(data= df, x= 'g0', y= 'g8', line_kws= {'color':'red'})

# %%
sns.lmplot(data= df, x= 'g0', y= 'g8', line_kws= {'color':'red'}, col='tratamento')

# %%
sns.lmplot(data= df, x= 'g0', y= 'g8', line_kws= {'color':'red'}, col='tratamento', row='tempo')

# %%
df.loc[:, 'g0': 'g771'].corr()
# Out:
#             g0        g1        g2  ...      g769      g770      g771
# g0    1.000000  0.086032  0.176188  ... -0.127375 -0.514201  0.405908
# g1    0.086032  1.000000 -0.054518  ... -0.006866 -0.095108 -0.032233
# g2    0.176188 -0.054518  1.000000  ...  0.014489 -0.078661  0.103985
# g3    0.011266 -0.027855  0.042633  ... -0.206077 -0.002142  0.058219
# g4    0.403153  0.193647  0.013968  ... -0.172727 -0.363673  0.250713
# ...        ...       ...       ...  ...       ...       ...       ...
# g767 -0.052622 -0.003378 -0.053149  ...  0.065450  0.008603 -0.001136
# g768  0.300241 -0.030756  0.115415  ...  0.079364 -0.382607  0.351651
# g769 -0.127375 -0.006866  0.014489  ...  1.000000  0.135853 -0.083713
# g770 -0.514201 -0.095108 -0.078661  ...  0.135853  1.000000 -0.425063
# g771  0.405908 -0.032233  0.103985  ... -0.083713 -0.425063  1.000000
#
# [772 rows x 772 columns]

# %%
corr = df.loc[:, 'g0': 'g50'].corr()

# %%
import numpy as np 

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
corr_celular = df.loc[:, 'c0': 'c50'].corr()

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_celular, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_celular, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
dr = pd.read_csv('https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_resultados.csv?raw=true')
dr.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dr.acat_inhibitor.unique()
# Out:
# array([0, 1])

# %%
### Seleciona somente as colunas por tipo, no caso, 'int64' pois só queremos os números, excluindo a coluna "id" que é tipo 'object'.
contagem_moa = dr.select_dtypes('int64').sum().sort_values(ascending = False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
### Outra maneira de selecionar é excluindo a coluna 'id com a função 'drop'.
contagem_moa = dr.drop('id', axis=1).sum().sort_values(ascending = False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
dr.drop('id', axis= 1).sum(axis=1)
# Out:
# 0        1
# 1        0
# 2        3
# 3        0
# 4        1
#         ..
# 23809    1
# 23810    1
# 23811    0
# 23812    1
# 23813    0
# Length: 23814, dtype: int64

# %%
dr.drop('id', axis= 1).sum(axis = 1).sort_values(ascending=False)
# Out:
# 21197    7
# 4849     7
# 19186    7
# 14316    7
# 20584    7
#         ..
# 6862     0
# 6861     0
# 11997    0
# 6859     0
# 23813    0
# Length: 23814, dtype: int64

# %%
dr['n_moa'] = dr.drop('id', axis=1).sum(axis=1)
dr.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  wnt_inhibitor  n_moa
# 0  id_000644bb2                            0  ...              0      1
# 1  id_000779bfc                            0  ...              0      0
# 2  id_000a6266a                            0  ...              0      3
# 3  id_0015fd391                            0  ...              0      0
# 4  id_001626bd3                            0  ...              0      1
#
# [5 rows x 208 columns]

# %%
dr.n_moa != 0
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 23809     True
# 23810     True
# 23811    False
# 23812     True
# 23813    False
# Name: n_moa, Length: 23814, dtype: bool

# %%
dr['ativo_moa'] = dr.n_moa != 0
dr
# Out:
#                  id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0      id_000644bb2                            0  ...      1       True
# 1      id_000779bfc                            0  ...      0      False
# 2      id_000a6266a                            0  ...      3       True
# 3      id_0015fd391                            0  ...      0      False
# 4      id_001626bd3                            0  ...      1       True
# ...             ...                          ...  ...    ...        ...
# 23809  id_fffb1ceed                            0  ...      1       True
# 23810  id_fffb70c0c                            0  ...      1       True
# 23811  id_fffc1c3f4                            0  ...      0      False
# 23812  id_fffcb9e7c                            0  ...      1       True
# 23813  id_ffffdd77b                            0  ...      0      False
#
# [23814 rows x 209 columns]

# %%
### pd.merge(df, dr [['id', 'n_moa', 'ativo_moa']], on = 'id' ) salvar numa variável:

d_comb = pd.merge(df, dr [['id', 'n_moa', 'ativo_moa']], on = 'id' )
d_comb
# Out:
#                  id    tratamento  tempo dose  ...     c98     c99  n_moa  ativo_moa
# 0      id_000644bb2     com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1      id_000779bfc     com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2      id_000a6266a     com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3      id_0015fd391     com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4      id_001626bd3     com_droga     72   D2  ... -0.3786  0.7125      1       True
# ...             ...           ...    ...  ...  ...     ...     ...    ...        ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.5258  0.4680      1       True
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2715  0.3689      1       True
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.6656  0.3808      0      False
# 23812  id_fffcb9e7c     com_droga     24   D1  ... -0.6290  0.0740      1       True
# ...

# %%
### Consultar se houve algum "ativo" nas amostras com_controle. 
d_comb.query('tratamento == "com_controle"')['ativo_moa'].value_counts()
##O correto é não haver, pois não foi usada qualquer droga nesse grupo.
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %%
### Consultar quantas amostras ativaram no tratamento com droga.
d_comb.query('tratamento == "com_droga"')['ativo_moa'].value_counts()
# Out:
# True     14447
# False     7501
# Name: ativo_moa, dtype: int64

# %%
comp_princ = d_comb.composto.value_counts().index[:5]
sns.boxplot(data = d_comb.query('composto in @comp_princ'), y= 'g8', x= 'composto', )

# %%
pd.get_dummies(d_comb, columns=['tratamento', 'tempo', 'dose'])
# Out:
#                  id   composto      g0  ...  tempo_72  dose_D1  dose_D2
# 0      id_000644bb2  b68db1d53  1.0620  ...         0        1        0
# 1      id_000779bfc  df89a8e5a  0.0743  ...         1        1        0
# 2      id_000a6266a  18bb41b2c  0.6280  ...         0        1        0
# 3      id_0015fd391  8c7f86626 -0.5138  ...         0        1        0
# 4      id_001626bd3  7cbed3131 -0.3254  ...         1        0        1
# ...             ...        ...     ...  ...       ...      ...      ...
# 23809  id_fffb1ceed  df1d0a5a1  0.1394  ...         0        0        1
# 23810  id_fffb70c0c  ecf3b6b74 -1.3260  ...         0        0        1
# 23811  id_fffc1c3f4  cacb2b860  0.3942  ...         0        0        1
# 23812  id_fffcb9e7c  8b87a7a83  0.6660  ...         0        1        0
# 23813  id_ffffdd77b  972f41291 -0.8598  ...         1        1        0
#
# [23814 rows x 883 columns]

# %%
df.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]
